# %% [markdown]
# # 4. Tiền xử lý dữ liệu và trực quan hóa dữ liệu lên đồ thị

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from bson.objectid import ObjectId

# %% [markdown]
# ## 4.2 Dữ liệu thực tế từ Website MXH

# %% [markdown]
# ### 4.2.1 Thiết lập kết nối tới DB MongoDB

# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://21522791:gCA40WsSzmA6ZsuI@dreamerdb.d0krlb2.mongodb.net/?retryWrites=true&w=majority&appName=DreamerDB"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ### 4.2.2 Lấy toàn bộ người dùng từ Collection "users"

# %%
mydb = client["test"]
userCollection = mydb["users"]

users = userCollection.find()

for user in users:
    print(user)
# Out:
# {'_id': ObjectId('654fbb2b40cfec0440aaf1c7'), 'birthday': datetime.datetime(2023, 12, 25, 0, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1716844137/DreamerDB/ls7bxxdfac8csv1pbz8o.jpg', 'role': 'user', 'gender': 'male', 'story': 'Xin chào mọi người, kết bạn với mình để trò chuyện nhé.\n', 'followers': [ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('658a8d484322ba2e40973103'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('657312b49fc6353b5046bd4e')], 'fullname': 'Nguyễn Hoàng Phúc', 'username': '_hoang.phuc.seiza_', 'email': 'user01@gmail.com', 'password': '$2b$12$SN1U7D2m3qhd4CeYTRMVKO8P1zjUV.WmWolmTaeDDmbPpiWaa4evG', 'createdAt': datetime.datetime(2023, 11, 11, 17, 34, 35, 753000), 'updatedAt': datetime.datetime(2024, 5, 28, 1, 31, 43, 967000), '__v': 0, 'website': 'https://www.facebook.com/hoangphucseiza', 'saved': [ObjectId('65757113c0adc23a44d61d9b'), ObjectId('657316f79fc6353b5046bd59'), ObjectId('6573191acb5de10ba8fa92eb'), ObjectId('6573171c9fc6353b5046bd5a'), ObjectId('657316a19fc6353b5046bd58'), ObjectId('658a86fe65c17c3d44e02b37'), ObjectId('658a86fe65c17c3d44e02b37'), ObjectId('658a891365c17c3d44e02b3a'), ObjectId('658a897365c17c3d44e02b3c'), ObjectId('6597d220cd7b40585880d04c')]}
# {'_id': ObjectId('654ff70ff81caf37a8d715ea'), 'birthday': datetime.datetime(2023, 12, 14, 0, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1713798949/DreamerDB/bmrh4acacptedwcqwflq.jpg', 'role': 'user', 'gender': 'male', 'story': "You Are the Apple of My Eye 🍎🍎. \nI'm in a field of dandelions 🪶🪶\nWishing on every one that you'd be mine, mine.", 'followers': [ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('658a8a556adc144b84875e50'), ObjectId('658a8d484322ba2e40973103'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5730e79d31ec889f5c5')], 'following': [ObjectId('657312b49fc6353b5046bd4e'), ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('658a8d484322ba2e40973103'), ObjectId('6550ee9b9cb73328506de7a3')], 'fullname': 'Nguyễn Hoàng Việt', 'username': 'hviet2003', 'email': 'vietdota12@gmail.com', 'password': '$2b$12$aRcEPbPzLnwm/D3EQlUEFuKzLQJrtJTOZSrm55WH53NgCJMk7D9Bi', 'createdAt': datetime.datetime(2023, 11, 11, 21, 50, 7, 501000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 5, 18, 746000), '__v': 0, 'website': 'https://www.facebook.com/NgyenHoangViet', 'saved': [ObjectId('65757113c0adc23a44d61d9b'), ObjectId('65697a6e8c234125384779fd')]}
# {'_id': ObjectId('654ffaa3130588273cc5bd99'), 'birthday': datetime.datetime(2023, 12, 7, 0, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1701862207/DreamerDB/tffpbpkhsbeqsyzzivdl.jpg', 'role': 'user', 'gender': 'male', 'story': 'Tìm người chung sở thích xem phim ', 'followers': [ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('654fbb2b40cfec0440aaf1c7')], 'fullname': 'Hồ Quang Đỉnh', 'username': '_dinh.wibu_', 'email': 'user03@gmail.com', 'password': '$2b$12$S4VpzMe/R.H6ZlqxildgoeGysRylQp40.Rym0O7TT6ksTyrBuEM1i', 'createdAt': datetime.datetime(2023, 11, 11, 22, 5, 23, 622000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 9, 987000), '__v': 0, 'website': 'https://www.facebook.com/wuangding', 'saved': []}
# {'_id': ObjectId('6550ee9b9cb73328506de7a3'), 'birthday': datetime.datetime(2010, 11, 12, 22, 25, 3, 60000), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1703175741/DreamerDB/xeznewxakqa5rotiwjer.jpg', 'role': 'user', 'gender': 'male', 'story': '', 'followers': [ObjectId('658a8d484322ba2e40973103'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f5f60e79d31ec889f5e4'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('654ff70ff81caf37a8d715ea')], 'fullname': 'Yushino', 'username': 'yushino', 'email': 'user04@gmail.com', 'password': '$2b$12$LgSFYXwvKE1Os/YOfxwYROACeNpM6OrxeR45sv8H3GBzB9HA0xmuq', 'createdAt': datetime.datetime(2023, 11, 12, 15, 26, 19, 86000), 'updatedAt': datetime.datetime(2024, 5, 28, 1, 31, 43, 712000), '__v': 0, 'saved': [], 'website': ''}
# {'_id': ObjectId('6551e902beb4280e4c0f2f0a'), 'birthday': datetime.datetime(1939, 11, 13, 16, 14, 13, 62000), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1703176022/DreamerDB/n5u2vgp3940j512den1e.jpg', 'role': 'user', 'gender': 'male', 'story': '', 'followers': [ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f5f60e79d31ec889f5e4'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('654ff70ff81caf37a8d715ea')], 'fullname': 'User05', 'username': 'best.memory__', 'email': 'user05@gmail.com', 'password': '$2b$12$PWqYsiNCpz.P3ZUIgK..YOW616VW0nGgdLrnZL/XDy7I3zeVsBQ/K', 'createdAt': datetime.datetime(2023, 11, 13, 9, 14, 42, 850000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 9, 147000), '__v': 0, 'saved': [], 'website': ''}
# {'_id': ObjectId('6561bb8ac147e12bd45d42ce'), 'birthday': datetime.datetime(2023, 11, 25, 9, 16, 13, 904000), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1703264709/DreamerDB/ee76rxxqximqmvcq8njs.jpg', 'role': 'user', 'gender': 'male', 'story': '', 'followers': [ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('658a8d484322ba2e40973103'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('654ff70ff81caf37a8d715ea')], 'fullname': 'Hà Thảo Dương', 'username': 'dundun', 'email': 'user06@gmail.com', 'password': '$2b$12$kh6MH/fh5DK3P4.xGsjhgeje58mhJSrB6oAGg4/YCRTcMPfZEyVCa', 'createdAt': datetime.datetime(2023, 11, 25, 9, 16, 58, 814000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 58, 921000), '__v': 0}
# {'_id': ObjectId('6561bbdf2f5d0539fc5a785a'), 'birthday': datetime.datetime(2023, 11, 25, 9, 16, 13, 904000), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1703264768/DreamerDB/eunqcrrqwlvkz7qhefi1.jpg', 'role': 'user', 'gender': 'male', 'story': '', 'followers': [ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('658a8a556adc144b84875e50'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5f60e79d31ec889f5e4'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('654ff70ff81caf37a8d715ea')], 'fullname': 'Thanh Nhàn', 'username': 'nhanpham', 'email': 'user07@gmail.com', 'password': '$2b$12$VzLY7uJRTh.7zjC94lH0m.6Dr.ITyV4.1Hq/CwVQgZp/bZ1t36P2G', 'createdAt': datetime.datetime(2023, 11, 25, 9, 18, 23, 309000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 4, 469000), '__v': 0}
# {'_id': ObjectId('656752403f8339224440f530'), 'birthday': datetime.datetime(1999, 9, 8, 17, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1703176104/DreamerDB/tevmadmhwypcgvvpd8zt.jpg', 'role': 'user', 'gender': 'male', 'story': '', 'followers': [ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f5f60e79d31ec889f5e4')], 'following': [], 'fullname': 'User08', 'username': 'tsun.sg', 'email': 'user08@gmail.com', 'password': '$2b$12$b7pBEvl97F6bfxmKccN/SeTz5TRugKPfNH/od6F8EZ0q8qF0v5uhe', 'createdAt': datetime.datetime(2023, 11, 29, 15, 1, 20, 639000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 16, 496000), '__v': 0, 'website': ''}
# {'_id': ObjectId('656849d63198ea3afc9e37ef'), 'birthday': datetime.datetime(1977, 7, 5, 17, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1703176214/DreamerDB/vssqdyk5imld8i3w5z8n.jpg', 'role': 'user', 'gender': 'male', 'story': '', 'followers': [ObjectId('658a8a556adc144b84875e50'), ObjectId('658a8d484322ba2e40973103'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('654ff70ff81caf37a8d715ea')], 'fullname': 'User09', 'username': 'dntlrdl', 'email': 'user09@gmail.com', 'password': '$2b$12$59G5LERjM1bPorQPNv.YBO0EZJ1vERYjEXJ91345h.fVhTOFLDuwy', 'createdAt': datetime.datetime(2023, 11, 30, 8, 37, 42, 74000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 54, 278000), '__v': 0, 'website': ''}
# {'_id': ObjectId('65684a74f0de8a23909ba7d9'), 'birthday': datetime.datetime(2013, 10, 10, 17, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1703267012/DreamerDB/typqhlwtm4j8sthmerhv.jpg', 'role': 'user', 'gender': 'male', 'story': '', 'followers': [ObjectId('658a8a556adc144b84875e50'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5f60e79d31ec889f5e4'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('654ff70ff81caf37a8d715ea')], 'fullname': 'Elizabeth Olsen', 'username': 'elizabeth', 'email': 'user10@gmail.com', 'password': '$2b$12$n/Gd5QrTP85WzJqyJz2kTe4Fz6KTURgHXxDKAl2Hv95YZWyAFBUli', 'createdAt': datetime.datetime(2023, 11, 30, 8, 40, 20, 953000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 59, 967000), '__v': 0}
# {'_id': ObjectId('657312b49fc6353b5046bd4e'), 'birthday': datetime.datetime(1981, 7, 5, 17, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1702040340/DreamerDB/unwcqgsecqcdoiezs4ca.jpg', 'role': 'user', 'gender': 'famale', 'story': 'Hi mấy anh trai, kết bạn với em nhé', 'website': 'https://www.facebook.com/anhhong8323', 'followers': [ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5cc0e79d31ec889f5da')], 'following': [ObjectId('654ff70ff81caf37a8d715ea')], 'saved': [], 'fullname': 'Ánh Hồng', 'username': '1nuhong_', 'email': 'user11@gmail.com', 'password': '$2b$12$RtjyMaLwkSwodKxmZXxj9OcP.kBtHHdYt99x.X0l3dD8cqUkWsN5a', 'createdAt': datetime.datetime(2023, 12, 8, 12, 57, 24, 458000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 6, 40, 324000), '__v': 0}
# {'_id': ObjectId('6573187bcb5de10ba8fa92ea'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1702041792/DreamerDB/flvqhwelmousx0xqpmkn.jpg', 'role': 'user', 'gender': 'famale', 'story': 'Tui là Hoàng Linh, tui rất thích mèo', 'website': 'https://www.facebook.com/hiimhoanglinh', 'followers': [ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [], 'saved': [], 'fullname': 'Hoàng Linh', 'username': 'delwyn.lph_', 'email': 'user12@gmail.com', 'password': '$2b$12$Q97l3pIOT8IVdMd9hIDomOowQxE4NgZncsVF52udw0eafq8ed5xXC', 'createdAt': datetime.datetime(2023, 12, 8, 13, 22, 3, 819000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 50, 970000), '__v': 0}
# {'_id': ObjectId('657b0a68953108fad57d0028'), 'birthday': datetime.datetime(2023, 12, 14, 0, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1701775180/DreamerDB/f4iwxihq1ha27dtdrexe.png', 'role': 'admin', 'gender': 'male', 'fullname': 'Nguyễn Hoàng Việt', 'email': 'adhviet@gmail.com', 'password': '$2b$12$Vl0f3M.f9W3OdXvTIS86ROjC9gddL1PhVGlz5WaRp1kZpvbybcDAC', 'createdAt': datetime.datetime(2023, 11, 11, 21, 50, 7, 501000), 'updatedAt': datetime.datetime(2024, 1, 4, 9, 55, 6, 52000), '__v': 0, 'followers': []}
# {'_id': ObjectId('6582feb4df8e015f44e26cf6'), 'birthday': datetime.datetime(2015, 2, 18, 0, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1703083850/DreamerDB/pyu0fm4rqvulyhkqywqw.jpg', 'role': 'user', 'gender': 'male', 'story': 'Chào mọi người, mình là A. Kết bạn với mình nha', 'website': 'https://www.facebook.com/hoangphucseiza/', 'followers': [ObjectId('658a8a556adc144b84875e50'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5f60e79d31ec889f5e4'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('654fbb2b40cfec0440aaf1c7')], 'saved': [ObjectId('6573164e9fc6353b5046bd57'), ObjectId('6573161d9fc6353b5046bd56'), ObjectId('657315c29fc6353b5046bd55')], 'fullname': 'Nguyễn Văn A', 'username': '@vana_haha', 'email': 'user20@gmail.com', 'password': '$2b$12$4H00Hzm.O.zquzPsGE5C5uFq.BbtUzKKC0LqXa0VmSqsjY1VQIHa.', 'createdAt': datetime.datetime(2023, 12, 20, 14, 48, 20, 741000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 50, 731000), '__v': 0}
# {'_id': ObjectId('6585bb530a44933edc12f0d5'), 'birthday': datetime.datetime(2023, 12, 22, 16, 37, 27, 299000), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'followers': [ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5f60e79d31ec889f5e4')], 'following': [], 'fullname': 'Nguyễn Hoàng Việt', 'username': '123456', 'email': 'user13@gmail.com', 'password': '$2b$12$6KrR0MOeeYSY5.SrYHOwYee92hGeW86chOQ8FHLCK3RprLU0Bdh4W', 'createdAt': datetime.datetime(2023, 12, 22, 16, 37, 39, 468000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 16, 232000), '__v': 0}
# {'_id': ObjectId('658a8a556adc144b84875e50'), 'birthday': datetime.datetime(1980, 7, 10, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('658a8d484322ba2e40973103'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('6561bbdf2f5d0539fc5a785a')], 'saved': [], 'fullname': 'Nguyễn Văn B', 'username': 'user25', 'email': 'user25@gmail.com', 'password': '$2b$12$ZiJAEQ92hWZoS6PfPAg4CeunMv69e49lb6jxFY39h0zNaOZhyEx4W', 'createdAt': datetime.datetime(2023, 12, 26, 8, 9, 57, 809000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 9, 125000), '__v': 0}
# {'_id': ObjectId('658a8d484322ba2e40973103'), 'birthday': datetime.datetime(2003, 1, 6, 0, 0), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1703579738/DreamerDB/kjxpefs7dxowsmeq5gya.jpg', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5f60e79d31ec889f5e4')], 'following': [ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('658a8a556adc144b84875e50'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('654ff70ff81caf37a8d715ea')], 'saved': [], 'fullname': 'Nguyễn Thị Bích Hảo', 'username': 'bithao', 'email': 'ntbh@123gmail.com', 'password': '$2b$12$Xj9vWVeT3xpV6LA6qUWipOanAWeVbrk969ZMkG7U.9o5QkXmCXEyC', 'createdAt': datetime.datetime(2023, 12, 26, 8, 22, 32, 527000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 11, 512000), '__v': 0}
# {'_id': ObjectId('658a969c6adc144b84875e6a'), 'birthday': datetime.datetime(1999, 7, 4, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('658a8d484322ba2e40973103'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('65684a74f0de8a23909ba7d9')], 'saved': [], 'fullname': 'Nguyễn Văn C', 'username': 'user30', 'email': 'user30@gmail.com', 'password': '$2b$12$VGVITW.F4yizA5OcMgULve4YritUOOUaP.rlFUBMyv8Tv.6jjU7Re', 'createdAt': datetime.datetime(2023, 12, 26, 9, 2, 20, 398000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 10, 221000), '__v': 0}
# {'_id': ObjectId('658e8ffe47a57302a4c5b97d'), 'birthday': datetime.datetime(2023, 12, 1, 16, 23, 4, 41000), 'avatar': 'https://res.cloudinary.com/dswg5in7u/image/upload/v1703841864/DreamerDB/u3b5yiopqtnemz8gmjnr.jpg', 'role': 'user', 'gender': 'male', 'story': '', 'followers': [ObjectId('654ffaa3130588273cc5bd99'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('654fbb2b40cfec0440aaf1c7')], 'fullname': 'Huỳnh Ngọc Quí', 'username': 'quichua333', 'email': 'quichua333@gmail.com', 'password': '$2b$12$Jv1Dep4VpuJMtciSCUUlLesxrjyyLs4RyrozL/gcqNqIvzpf0nF76', 'createdAt': datetime.datetime(2023, 12, 29, 9, 23, 10, 817000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 54, 833000), '__v': 0}
# {'_id': ObjectId('6654f2c20e79d31ec889f520'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('658a8a556adc144b84875e50'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('658a8d484322ba2e40973103'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('656752403f8339224440f530'), ObjectId('654ffaa3130588273cc5bd99')], 'saved': [], 'fullname': 'User 31', 'username': 'user31', 'email': 'user31@gmail.com', 'password': '$2b$12$c0cFc.72lhMsYSQT7LL2ge6noORU8wYs/56hYXbAYmoJZ4xHx6hnq', 'createdAt': datetime.datetime(2024, 5, 27, 20, 53, 22, 871000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 8, 576000), '__v': 0}
# {'_id': ObjectId('6654f2f10e79d31ec889f52b'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f5f60e79d31ec889f5e4')], 'following': [ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('658a8a556adc144b84875e50'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('658a8d484322ba2e40973103'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('658a969c6adc144b84875e6a')], 'saved': [], 'fullname': 'User 32', 'username': 'user32', 'email': 'user32@gmail.com', 'password': '$2b$12$DSlg8myau4Bgc9eSEGLNweUs.J00s/uTx0gebXeLR7PwnbNOrYWa.', 'createdAt': datetime.datetime(2024, 5, 27, 20, 54, 9, 436000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 21, 946000), '__v': 0}
# {'_id': ObjectId('6654f31b0e79d31ec889f538'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('658a8d484322ba2e40973103'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('656752403f8339224440f530'), ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('658a8a556adc144b84875e50')], 'saved': [], 'fullname': 'User 33', 'username': 'user33', 'email': 'user33@gmail.com', 'password': '$2b$12$7PSoYE5YpcpqTM8wOeHM1.ozX4cW9WcEvG1aPKyGKKmz1eY0IrQLe', 'createdAt': datetime.datetime(2024, 5, 27, 20, 54, 51, 467000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 59, 550000), '__v': 0}
# {'_id': ObjectId('6654f34a0e79d31ec889f544'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5f60e79d31ec889f5e4'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('658a969c6adc144b84875e6a'), ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('658a8a556adc144b84875e50'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('6654f2f10e79d31ec889f52b')], 'saved': [], 'fullname': 'User 35', 'username': 'user35', 'email': 'user35@gmail.com', 'password': '$2b$12$vonkqTS47l3AGq2hpTjfQ.zL4NDKU7AY016WMlXPeTWe4tZ3z5xoq', 'createdAt': datetime.datetime(2024, 5, 27, 20, 55, 38, 507000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 51, 104000), '__v': 0}
# {'_id': ObjectId('6654f3820e79d31ec889f550'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('656752403f8339224440f530'), ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('6585bb530a44933edc12f0d5')], 'saved': [], 'fullname': 'User 36', 'username': 'user36', 'email': 'user36@gmail.com', 'password': '$2b$12$WjmLBHOkrJzOgCkGTNTBUOyDav8aldvGaeA.3MTbbCJiJZgcNrlS6', 'createdAt': datetime.datetime(2024, 5, 27, 20, 56, 34, 945000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 4, 470000), '__v': 0}
# {'_id': ObjectId('6654f3b30e79d31ec889f55c'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5f60e79d31ec889f5e4')], 'following': [ObjectId('6585bb530a44933edc12f0d5'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('658a8d484322ba2e40973103'), ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('6654f31b0e79d31ec889f538')], 'saved': [], 'fullname': 'User 37', 'username': 'user37', 'email': 'user37@gmail.com', 'password': '$2b$12$aFuQWt4y.efjRtRK9ZPbiuz6mr8d61cHBuhUjBHw56ehMC04fZq7y', 'createdAt': datetime.datetime(2024, 5, 27, 20, 57, 23, 3000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 21, 348000), '__v': 0}
# {'_id': ObjectId('6654f3dc0e79d31ec889f568'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6654f5f60e79d31ec889f5e4'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('6654f2c20e79d31ec889f520'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('656752403f8339224440f530'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('658a8d484322ba2e40973103'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('65684a74f0de8a23909ba7d9')], 'saved': [], 'fullname': 'User 38', 'username': 'user38', 'email': 'user38@gmail.com', 'password': '$2b$12$PNCYGs1OEvYkDDOGmp7Px.FANb2h64RmqayMDgfvC13jmQe/MNTZy', 'createdAt': datetime.datetime(2024, 5, 27, 20, 58, 4, 568000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 59, 710000), '__v': 0}
# {'_id': ObjectId('6654f41a0e79d31ec889f573'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('658a8d484322ba2e40973103'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('658a969c6adc144b84875e6a')], 'saved': [], 'fullname': 'User 39', 'username': 'user39', 'email': 'user39@gmail.com', 'password': '$2b$12$pzi6dOfbXT2bdxu0rfOjsuPY6iB0Ytez0NuYYxJW3QnkrIXl/4AF.', 'createdAt': datetime.datetime(2024, 5, 27, 20, 59, 6, 396000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 3, 913000), '__v': 0}
# {'_id': ObjectId('6654f44c0e79d31ec889f57f'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5730e79d31ec889f5c5'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('658a8a556adc144b84875e50'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('658a8d484322ba2e40973103'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('656752403f8339224440f530'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('6654f2f10e79d31ec889f52b')], 'saved': [], 'fullname': 'User 40', 'username': 'user40', 'email': 'user40@gmail.com', 'password': '$2b$12$UUtKFzedDo3cbLFsRroh8uzuBhJ13z9z5fDOe7iu.i0JSRCOhRz8e', 'createdAt': datetime.datetime(2024, 5, 27, 20, 59, 56, 312000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 55, 141000), '__v': 0}
# {'_id': ObjectId('6654f4760e79d31ec889f58a'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5f60e79d31ec889f5e4'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('656752403f8339224440f530'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('658a8d484322ba2e40973103'), ObjectId('6573187bcb5de10ba8fa92ea')], 'saved': [], 'fullname': 'User 41', 'username': 'user41', 'email': 'user41@gmail.com', 'password': '$2b$12$JeubEwlqhvyHDaZ7hWv1lOScQx7/1TJVSoX2FReHeahbDgsWhUuli', 'createdAt': datetime.datetime(2024, 5, 27, 21, 0, 38, 677000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 50, 407000), '__v': 0}
# {'_id': ObjectId('6654f4aa0e79d31ec889f595'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5cc0e79d31ec889f5da')], 'following': [ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('658a8a556adc144b84875e50'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('658a8d484322ba2e40973103')], 'saved': [], 'fullname': 'User 42', 'username': 'user42', 'email': 'user42@gmail.com', 'password': '$2b$12$eDNmeQkUAtzNDTKGD.gMtehQulMtvgbhbx0WfZBKXBv0JXl.6td/C', 'createdAt': datetime.datetime(2024, 5, 27, 21, 1, 30, 44000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 6, 39, 255000), '__v': 0}
# {'_id': ObjectId('6654f4e60e79d31ec889f5a3'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('656752403f8339224440f530'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('656849d63198ea3afc9e37ef')], 'saved': [], 'fullname': 'User 43', 'username': 'user43', 'email': 'user43@gmail.com', 'password': '$2b$12$HDXWIITj27Ph/kxHsGxbr.CQo22CW5jWnozyB5cRHcCtgCEAS4BV2', 'createdAt': datetime.datetime(2024, 5, 27, 21, 2, 30, 747000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 55, 398000), '__v': 0}
# {'_id': ObjectId('6654f5180e79d31ec889f5aa'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f5f60e79d31ec889f5e4')], 'following': [ObjectId('6654f4760e79d31ec889f58a'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('658a8a556adc144b84875e50'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('656752403f8339224440f530'), ObjectId('658a8d484322ba2e40973103'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('658e8ffe47a57302a4c5b97d')], 'saved': [], 'fullname': 'User 44', 'username': 'user44', 'email': 'user44@gmail.com', 'password': '$2b$12$Z4ggH24O7H1P8jwwWeDgCOMS8RmSGx.b.2L0jttRVcKTwrxKfAFEe', 'createdAt': datetime.datetime(2024, 5, 27, 21, 3, 20, 456000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 15, 452000), '__v': 0}
# {'_id': ObjectId('6654f5470e79d31ec889f5b7'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f5f60e79d31ec889f5e4')], 'following': [ObjectId('654ffaa3130588273cc5bd99'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('656752403f8339224440f530'), ObjectId('658a8a556adc144b84875e50'), ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f2f10e79d31ec889f52b')], 'saved': [], 'fullname': 'User 45', 'username': 'user45', 'email': 'user45@gmail.com', 'password': '$2b$12$uqgHOznI73e9L.Mwz/ZyvOND3kstyof9zdp24PsiesXi6gvZQeN4q', 'createdAt': datetime.datetime(2024, 5, 27, 21, 4, 7, 16000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 21, 888000), '__v': 0}
# {'_id': ObjectId('6654f5730e79d31ec889f5c5'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f5a30e79d31ec889f5cf')], 'following': [ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('656752403f8339224440f530'), ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('654ff70ff81caf37a8d715ea'), ObjectId('658a969c6adc144b84875e6a')], 'saved': [], 'fullname': 'User 46', 'username': 'user46', 'email': 'user46@gmail.com', 'password': '$2b$12$m2vwZgtEFy6P36VloHtb0.s9DIUbD.a42xdbUr4SWygpdsBSQjfm6', 'createdAt': datetime.datetime(2024, 5, 27, 21, 4, 51, 532000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 6, 3, 109000), '__v': 0}
# {'_id': ObjectId('6654f5a30e79d31ec889f5cf'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('658a969c6adc144b84875e6a'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('6654f5730e79d31ec889f5c5')], 'saved': [], 'fullname': 'User 47', 'username': 'user47', 'email': 'user47@gmail.com', 'password': '$2b$12$uvVf3Nm0cYFzp54s37PMOe5pH4bXzb4ZBKU6c8UmO6BKT9ZC.xS/e', 'createdAt': datetime.datetime(2024, 5, 27, 21, 5, 39, 371000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 0, 80000), '__v': 0}
# {'_id': ObjectId('6654f5cc0e79d31ec889f5da'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f2f10e79d31ec889f52b'), ObjectId('656752403f8339224440f530'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f4aa0e79d31ec889f595'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('657312b49fc6353b5046bd4e'), ObjectId('6654f5470e79d31ec889f5b7')], 'saved': [], 'fullname': 'User 48', 'username': 'user48', 'email': 'user48@gmail.com', 'password': '$2b$12$58PQOGYEkbuUGFzIrGqTI.SWNN59EMJVsLcUJEI2GMWOlXAho.Gt2', 'createdAt': datetime.datetime(2024, 5, 27, 21, 6, 20, 546000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 4, 802000), '__v': 0}
# {'_id': ObjectId('6654f5f60e79d31ec889f5e4'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [ObjectId('6654f61b0e79d31ec889f5ee')], 'following': [ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('658a8d484322ba2e40973103'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('6654f5180e79d31ec889f5aa'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6585bb530a44933edc12f0d5'), ObjectId('656752403f8339224440f530'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('6654f3b30e79d31ec889f55c'), ObjectId('6654f5470e79d31ec889f5b7'), ObjectId('6654f2f10e79d31ec889f52b')], 'saved': [], 'fullname': 'User 49', 'username': 'user49', 'email': 'user49@gmail.com', 'password': '$2b$12$6UcIJpk9xTfyCFZ8uvHMK.QSv5xSGXB42CbenHoS/FjR7lPfNqW/a', 'createdAt': datetime.datetime(2024, 5, 27, 21, 7, 2, 170000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 7, 55, 333000), '__v': 0}
# {'_id': ObjectId('6654f61b0e79d31ec889f5ee'), 'birthday': datetime.datetime(1969, 12, 31, 17, 0), 'avatar': 'https://static-00.iconduck.com/assets.00/avatar-default-symbolic-icon-2048x1949-pq9uiebg.png', 'role': 'user', 'gender': 'male', 'story': '', 'website': '', 'followers': [], 'following': [ObjectId('6550ee9b9cb73328506de7a3'), ObjectId('6654f4760e79d31ec889f58a'), ObjectId('6582feb4df8e015f44e26cf6'), ObjectId('6573187bcb5de10ba8fa92ea'), ObjectId('6654f34a0e79d31ec889f544'), ObjectId('656849d63198ea3afc9e37ef'), ObjectId('658e8ffe47a57302a4c5b97d'), ObjectId('6654f44c0e79d31ec889f57f'), ObjectId('6654f5f60e79d31ec889f5e4'), ObjectId('6654f4e60e79d31ec889f5a3'), ObjectId('6561bb8ac147e12bd45d42ce'), ObjectId('6654f31b0e79d31ec889f538'), ObjectId('6654f3dc0e79d31ec889f568'), ObjectId('65684a74f0de8a23909ba7d9'), ObjectId('6654f5a30e79d31ec889f5cf'), ObjectId('6654f41a0e79d31ec889f573'), ObjectId('6561bbdf2f5d0539fc5a785a'), ObjectId('6654f3820e79d31ec889f550'), ObjectId('6654f5cc0e79d31ec889f5da'), ObjectId('654fbb2b40cfec0440aaf1c7'), ObjectId('6654f2c20e79d31ec889f520'), ObjectId('658a8a556adc144b84875e50'), ObjectId('6551e902beb4280e4c0f2f0a'), ObjectId('654ffaa3130588273cc5bd99'), ObjectId('658a969c6adc144b84875e6a')], 'saved': [], 'fullname': 'User 50', 'username': 'user50', 'email': 'user50@gmail.com', 'password': '$2b$12$9.hlZXRhZDHv0/Q.C5fHTe9KV86tk.aFJeRYqAJlfZuKdCY6pMKIq', 'createdAt': datetime.datetime(2024, 5, 27, 21, 7, 39, 952000), 'updatedAt': datetime.datetime(2024, 5, 27, 21, 8, 10, 478000), '__v': 0}

# %% [markdown]
# ### 4.2.3 Chuyển dữ liệu người dùng thành tập đỉnh và tập cạnh có hướng

# %%
users = userCollection.find({"role": "user"})
nodes_list = []
edges_list = [];

for user in users:
    user_id = str(user['_id'])
    nodes_list.append(user_id)
    following = user['following']
    for followed_user in following:
        followed_user_id = str(followed_user)
        edges_list.append([user_id, followed_user_id])
        
print(edges_list)
# Out:
# [['654fbb2b40cfec0440aaf1c7', '6561bbdf2f5d0539fc5a785a'], ['654fbb2b40cfec0440aaf1c7', '6561bb8ac147e12bd45d42ce'], ['654fbb2b40cfec0440aaf1c7', '654ffaa3130588273cc5bd99'], ['654fbb2b40cfec0440aaf1c7', '654ff70ff81caf37a8d715ea'], ['654fbb2b40cfec0440aaf1c7', '657312b49fc6353b5046bd4e'], ['654ff70ff81caf37a8d715ea', '657312b49fc6353b5046bd4e'], ['654ff70ff81caf37a8d715ea', '6573187bcb5de10ba8fa92ea'], ['654ff70ff81caf37a8d715ea', '6561bbdf2f5d0539fc5a785a'], ['654ff70ff81caf37a8d715ea', '654fbb2b40cfec0440aaf1c7'], ['654ff70ff81caf37a8d715ea', '6561bb8ac147e12bd45d42ce'], ['654ff70ff81caf37a8d715ea', '6582feb4df8e015f44e26cf6'], ['654ff70ff81caf37a8d715ea', '658a8d484322ba2e40973103'], ['654ff70ff81caf37a8d715ea', '6550ee9b9cb73328506de7a3'], ['654ffaa3130588273cc5bd99', '658e8ffe47a57302a4c5b97d'], ['654ffaa3130588273cc5bd99', '654ff70ff81caf37a8d715ea'], ['654ffaa3130588273cc5bd99', '654fbb2b40cfec0440aaf1c7'], ['6550ee9b9cb73328506de7a3', '654fbb2b40cfec0440aaf1c7'], ['6550ee9b9cb73328506de7a3', '654ff70ff81caf37a8d715ea'], ['6551e902beb4280e4c0f2f0a', '654ff70ff81caf37a8d715ea'], ['6561bb8ac147e12bd45d42ce', '654ff70ff81caf37a8d715ea'], ['6561bbdf2f5d0539fc5a785a', '654ff70ff81caf37a8d715ea'], ['656849d63198ea3afc9e37ef', '654ff70ff81caf37a8d715ea'], ['65684a74f0de8a23909ba7d9', '654ff70ff81caf37a8d715ea'], ['657312b49fc6353b5046bd4e', '654ff70ff81caf37a8d715ea'], ['6582feb4df8e015f44e26cf6', '6573187bcb5de10ba8fa92ea'], ['6582feb4df8e015f44e26cf6', '657312b49fc6353b5046bd4e'], ['6582feb4df8e015f44e26cf6', '654fbb2b40cfec0440aaf1c7'], ['658a8a556adc144b84875e50', '654ff70ff81caf37a8d715ea'], ['658a8a556adc144b84875e50', '65684a74f0de8a23909ba7d9'], ['658a8a556adc144b84875e50', '656849d63198ea3afc9e37ef'], ['658a8a556adc144b84875e50', '6582feb4df8e015f44e26cf6'], ['658a8a556adc144b84875e50', '6561bbdf2f5d0539fc5a785a'], ['658a8d484322ba2e40973103', '6550ee9b9cb73328506de7a3'], ['658a8d484322ba2e40973103', '658a8a556adc144b84875e50'], ['658a8d484322ba2e40973103', '654fbb2b40cfec0440aaf1c7'], ['658a8d484322ba2e40973103', '656849d63198ea3afc9e37ef'], ['658a8d484322ba2e40973103', '6561bb8ac147e12bd45d42ce'], ['658a8d484322ba2e40973103', '654ff70ff81caf37a8d715ea'], ['658a969c6adc144b84875e6a', '654ff70ff81caf37a8d715ea'], ['658a969c6adc144b84875e6a', '654fbb2b40cfec0440aaf1c7'], ['658a969c6adc144b84875e6a', '658e8ffe47a57302a4c5b97d'], ['658a969c6adc144b84875e6a', '6561bbdf2f5d0539fc5a785a'], ['658a969c6adc144b84875e6a', '6550ee9b9cb73328506de7a3'], ['658a969c6adc144b84875e6a', '658a8d484322ba2e40973103'], ['658a969c6adc144b84875e6a', '6551e902beb4280e4c0f2f0a'], ['658a969c6adc144b84875e6a', '6585bb530a44933edc12f0d5'], ['658a969c6adc144b84875e6a', '654ffaa3130588273cc5bd99'], ['658a969c6adc144b84875e6a', '656849d63198ea3afc9e37ef'], ['658a969c6adc144b84875e6a', '657312b49fc6353b5046bd4e'], ['658a969c6adc144b84875e6a', '65684a74f0de8a23909ba7d9'], ['658e8ffe47a57302a4c5b97d', '654fbb2b40cfec0440aaf1c7'], ['6654f2c20e79d31ec889f520', '654ff70ff81caf37a8d715ea'], ['6654f2c20e79d31ec889f520', '6551e902beb4280e4c0f2f0a'], ['6654f2c20e79d31ec889f520', '658a8a556adc144b84875e50'], ['6654f2c20e79d31ec889f520', '6561bbdf2f5d0539fc5a785a'], ['6654f2c20e79d31ec889f520', '658e8ffe47a57302a4c5b97d'], ['6654f2c20e79d31ec889f520', '657312b49fc6353b5046bd4e'], ['6654f2c20e79d31ec889f520', '656849d63198ea3afc9e37ef'], ['6654f2c20e79d31ec889f520', '65684a74f0de8a23909ba7d9'], ['6654f2c20e79d31ec889f520', '658a8d484322ba2e40973103'], ['6654f2c20e79d31ec889f520', '654fbb2b40cfec0440aaf1c7'], ['6654f2c20e79d31ec889f520', '656752403f8339224440f530'], ['6654f2c20e79d31ec889f520', '654ffaa3130588273cc5bd99'], ['6654f2f10e79d31ec889f52b', '6550ee9b9cb73328506de7a3'], ['6654f2f10e79d31ec889f52b', '658e8ffe47a57302a4c5b97d'], ['6654f2f10e79d31ec889f52b', '656849d63198ea3afc9e37ef'], ['6654f2f10e79d31ec889f52b', '658a8a556adc144b84875e50'], ['6654f2f10e79d31ec889f52b', '65684a74f0de8a23909ba7d9'], ['6654f2f10e79d31ec889f52b', '6561bb8ac147e12bd45d42ce' ...

# %% [markdown]
# ### 4.2.4 Chuyển dữ liệu thành đồ thị

# %%
G_users = nx.DiGraph()
G_users.add_nodes_from(nodes_list)
G_users.add_edges_from(edges_list)

# %% [markdown]
# ### 4.2.5 Thống kê một số độ đo của đồ thị

# %%
num_nodes = G_users.number_of_nodes()
num_edges = G_users.number_of_edges()
max_degree = np.max
clustering_coefficient = nx.average_clustering(G_users)
degrees = dict(G_users.degree())
max_degree_node = max(degrees, key=degrees.get)
max_degree = degrees[max_degree_node]
min_degree_node = min(degrees, key=degrees.get)
min_degree = degrees[min_degree_node]

# Hiển thị thống kê
print(f"Số lượng nút: {num_nodes}")
print(f"Số lượng cạnh: {num_edges}")
print(f"Đỉnh {max_degree_node} có bậc cao nhất: {max_degree}")
print(f"Đỉnh {min_degree_node} có bậc thấp nhất: {min_degree}")
print(f"Hệ số phân cụm trung bình: {clustering_coefficient:.4f}")
# Out:
# Số lượng nút: 37
# Số lượng cạnh: 344
# Đỉnh 654ff70ff81caf37a8d715ea có bậc cao nhất: 33
# Đỉnh 656752403f8339224440f530 có bậc thấp nhất: 12
# Hệ số phân cụm trung bình: 0.2741

# %%
# plot graph
plt.figure(figsize=(10,8))

pos = nx.random_layout(G_users, seed=23)
nx.draw(G_users,  pos = pos, node_size = 200, alpha = 0.8, width = 1)

# plt.savefig("graph_users.png")
plt.show()

# %% [markdown]
# # 6. ÁP DỤNG THUẬT TOÁN DỰ ĐOÁN LIÊN KẾT VÀO TRANG WEB MẠNG XÃ HỘI

# %% [markdown]
# ## Mô phỏng tình huống và trực quan hóa dữ liệu người dùng cần dự đoán

# %% [markdown]
# ### Kiểm tra các node và cặp cạnh có liên kết với node cần dự đoán

# %%
# Kiểm tra các node kề với node cần dự đoán
predict_node = '654fbb2b40cfec0440aaf1c7'

neighbor_nodes = set(G_users.neighbors(predict_node))
connected_edges = [(predict_node, neighbor) for neighbor in neighbor_nodes]

print(f"Số lượng đỉnh kề với đỉnh dự đoán là {len(neighbor_nodes)}: ", neighbor_nodes)
print(f"Số lượng cạnh có liên kết từ đỉnh dự đoán là {len(connected_edges)}: ", connected_edges)
# Out:
# Số lượng đỉnh kề với đỉnh dự đoán là 5:  {'654ffaa3130588273cc5bd99', '657312b49fc6353b5046bd4e', '6561bbdf2f5d0539fc5a785a', '6561bb8ac147e12bd45d42ce', '654ff70ff81caf37a8d715ea'}
# Số lượng cạnh có liên kết từ đỉnh dự đoán là 5:  [('654fbb2b40cfec0440aaf1c7', '654ffaa3130588273cc5bd99'), ('654fbb2b40cfec0440aaf1c7', '657312b49fc6353b5046bd4e'), ('654fbb2b40cfec0440aaf1c7', '6561bbdf2f5d0539fc5a785a'), ('654fbb2b40cfec0440aaf1c7', '6561bb8ac147e12bd45d42ce'), ('654fbb2b40cfec0440aaf1c7', '654ff70ff81caf37a8d715ea')]

# %%
# Vẽ đồ thị với đỉnh cần dự đoán
other_edges = [edge for edge in G_users.edges() if edge not in connected_edges]

plt.figure(figsize=(12,8))
pos = nx.random_layout(G_users, seed=23, center=[0,0])

nx.draw(G_users,  pos = pos, node_size = 300, alpha = 0.8, width = 1)
nx.draw_networkx_edges(G_users, pos, edgelist=other_edges, edge_color='#BBBBBB',width=0.5, alpha=0.5)
nx.draw_networkx_edges(G_users, pos, edgelist=connected_edges, edge_color='black', width=2)
nx.draw_networkx_nodes(G_users, pos=pos, nodelist=[predict_node], node_color='red')
nx.draw_networkx_nodes(G_users, pos=pos, nodelist=neighbor_nodes, node_color='orange')

# %% [markdown]
# ### Liệt kê danh sách các cạnh chưa có liên kết từ đỉnh cần dự đoán

# %%
all_nodes = set(G_users.nodes())

unconnected_nodes = all_nodes - neighbor_nodes - {predict_node}
unconnected_edges = [(predict_node, node) for node in unconnected_nodes]

# In danh sách các cặp đỉnh chưa có liên kết
print("Số lượng cặp đỉnh mà đỉnh dự đoán chưa có liên kết đến: ", len(unconnected_nodes))
print("Danh sách các cặp đỉnh mà đỉnh dự đoán chưa có liên kết đến: ")
for edge in unconnected_edges:
    print(edge)
# Out:
# Số lượng cặp đỉnh mà đỉnh dự đoán chưa có liên kết đến:  31
# Danh sách các cặp đỉnh mà đỉnh dự đoán chưa có liên kết đến:
# ('654fbb2b40cfec0440aaf1c7', '6654f2f10e79d31ec889f52b')
# ('654fbb2b40cfec0440aaf1c7', '6654f31b0e79d31ec889f538')
# ('654fbb2b40cfec0440aaf1c7', '658a969c6adc144b84875e6a')
# ('654fbb2b40cfec0440aaf1c7', '6654f5730e79d31ec889f5c5')
# ('654fbb2b40cfec0440aaf1c7', '6654f5470e79d31ec889f5b7')
# ('654fbb2b40cfec0440aaf1c7', '6585bb530a44933edc12f0d5')
# ('654fbb2b40cfec0440aaf1c7', '656752403f8339224440f530')
# ('654fbb2b40cfec0440aaf1c7', '6654f5cc0e79d31ec889f5da')
# ('654fbb2b40cfec0440aaf1c7', '6654f4e60e79d31ec889f5a3')
# ('654fbb2b40cfec0440aaf1c7', '6654f2c20e79d31ec889f520')
# ('654fbb2b40cfec0440aaf1c7', '6654f5180e79d31ec889f5aa')
# ('654fbb2b40cfec0440aaf1c7', '6654f61b0e79d31ec889f5ee')
# ('654fbb2b40cfec0440aaf1c7', '656849d63198ea3afc9e37ef')
# ('654fbb2b40cfec0440aaf1c7', '6654f4aa0e79d31ec889f595')
# ('654fbb2b40cfec0440aaf1c7', '6582feb4df8e015f44e26cf6')
# ('654fbb2b40cfec0440aaf1c7', '658a8d484322ba2e40973103')
# ('654fbb2b40cfec0440aaf1c7', '6654f34a0e79d31ec889f544')
# ('654fbb2b40cfec0440aaf1c7', '6654f41a0e79d31ec889f573')
# ('654fbb2b40cfec0440aaf1c7', '6573187bcb5de10ba8fa92ea')
# ('654fbb2b40cfec0440aaf1c7', '65684a74f0de8a23909ba7d9')
# ('654fbb2b40cfec0440aaf1c7', '6654f4760e79d31ec889f58a')
# ('654fbb2b40cfec0440aaf1c7', '658e8ffe47a57302a4c5b97d')
# ('654fbb2b40cfec0440aaf1c7', '6654f3820e79d31ec889f550')
# ('654fbb2b40cfec0440aaf1c7', '6654f3b30e79d31ec889f55c')
# ('654fbb2b40cfec0440aaf1c7', '658a8a556adc144b84875e50')
# ('654fbb2b40cfec0440aaf1c7', '6654f44c0e79d31ec889f57f')
# ('654fbb2b40cfec0440aaf1c7', '6550ee9b9cb73328506de7a3')
# ('654fbb2b40cfec0440aaf1c7', '6654f5a30e79d31ec889f5cf')
# ('654fbb2b40cfec0440aaf1c7', '6654f3dc0e79d31ec889f568')
# ('654fbb2b40cfec0440aaf1c7', '6654f5f60e79d31ec889f5e4')
# ('654fbb2b40cfec0440aaf1c7', '6551e902beb4280e4c0f2f0a')

# %%
plt.figure(figsize=(16,8))
pos = nx.random_layout(G_users, seed=23, center=[0,0])


nx.draw_networkx_edges(G_users, pos, edgelist=connected_edges, edge_color='black', width=1.5)
nx.draw_networkx_edges(G_users, pos, edgelist=unconnected_edges, edge_color='grey', style='dashed')
nx.draw_networkx_nodes(G_users, pos=pos, nodelist=set(G_users.nodes))
nx.draw_networkx_nodes(G_users, pos=pos, nodelist=[predict_node], node_color='red')
nx.draw_networkx_nodes(G_users, pos=pos, nodelist=neighbor_nodes, node_color='orange');

# %% [markdown]
# ## 6.1 Thuật toán Common Neighbors (CN)

# %%
def top_common_non_neighbours(graph, node):
    # Danh sách tất cả các node trong đồ thị
    all_nodes = set(graph.nodes())
    
    # Tập hợp các hàng xóm của node cho trước
    neighbors = set(graph.neighbors(node))
    
    # Tập hợp các node không phải là hàng xóm của node cho trước
    non_neighbors = all_nodes - neighbors - {node}
    
    # Dictionary lưu số lượng hàng xóm chung của mỗi non-neighbor
    common_neighbours = {}
    
    # Lặp qua từng non-neighbor
    for non_neighbor in non_neighbors:
        # Tập hợp các hàng xóm của non-neighbor
        non_neighbor_neighbors = set(graph.neighbors(non_neighbor))
        
        # Tính số lượng hàng xóm chung giữa node và non-neighbor
        common_count = len(neighbors.intersection(non_neighbor_neighbors))
        
        # Lưu số lượng hàng xóm chung vào dictionary
        common_neighbours[non_neighbor] = common_count
    
    # Sắp xếp dictionary theo số lượng hàng xóm chung giảm dần
    sorted_common_neighbours = sorted(common_neighbours.items(), key=lambda x: x[1], reverse=True)
    
    # Lấy 5 non-neighbor có số lượng hàng xóm chung lớn nhất
    top_5_common_non_neighbours = [non_neighbor for non_neighbor, count in sorted_common_neighbours[:5]]
    
    return top_5_common_non_neighbours

# %%
# Ví dụ sử dụng
node = '654fbb2b40cfec0440aaf1c7' # username : _hoang.phuc.seiza_
top5_cn = top_common_non_neighbours(G_users, node)
print(top5_cn)
# Out:
# ['6654f2f10e79d31ec889f52b', '6654f2c20e79d31ec889f520', '6654f4aa0e79d31ec889f595', '6654f3820e79d31ec889f550', '6654f31b0e79d31ec889f538']

# %%
query = {"_id": {"$in": [ObjectId(user) for user in top5_cn]}}
top5_predict_users = userCollection.find(query)


for user in top5_predict_users:
    print(f"_id: {user['_id']} - username: {user['username']}")
# Out:
# _id: 6654f2c20e79d31ec889f520 - username: user31
# _id: 6654f2f10e79d31ec889f52b - username: user32
# _id: 6654f31b0e79d31ec889f538 - username: user33
# _id: 6654f3820e79d31ec889f550 - username: user36
# _id: 6654f4aa0e79d31ec889f595 - username: user42

# %% [markdown]
# ## 6.2 Thuật toán Jaccard (JC)

# %%
def top_jaccard_non_neighbors(graph, node):
    # Danh sách tất cả các node trong đồ thị
    all_nodes = set(graph.nodes())
    
    # Tập hợp các neighbor của node cho trước
    neighbors = set(graph.neighbors(node))
    
    # Tập hợp các non-neighbor (tất cả các node trừ chính node đó và các neighbor của nó)
    non_neighbors = all_nodes - neighbors - {node}
    
    # Từ điển để lưu chỉ số Jaccard cho mỗi non-neighbor
    jaccard_index = {}

    # Lặp qua từng non-neighbor
    for non_neighbor in non_neighbors:
        # Tập hợp các neighbor của non-neighbor hiện tại
        non_neighbor_neighbors = set(graph.neighbors(non_neighbor))
        
        # Tính chỉ số Jaccard
        intersection_size = len(neighbors.intersection(non_neighbor_neighbors))
        union_size = len(neighbors.union(non_neighbor_neighbors))
        if union_size != 0:
            jaccard_index[non_neighbor] = intersection_size / union_size
        else:
            jaccard_index[non_neighbor] = 0

    # Sắp xếp các non-neighbor theo chỉ số Jaccard giảm dần
    sorted_non_neighbors = sorted(jaccard_index.items(), key=lambda x: x[1], reverse=True)

    # Lấy 5 non-neighbor có chỉ số Jaccard cao nhất
    top_5_jaccard_non_neighbors = [non_neighbor for non_neighbor, index in sorted_non_neighbors[:5]]

    return top_5_jaccard_non_neighbors

# %%
# Ví dụ sử dụng
node = '654fbb2b40cfec0440aaf1c7' # username : _hoang.phuc.seiza_
top5_jaccard = top_jaccard_non_neighbors(G_users, node)
print(top5_jaccard)
# Out:
# ['6654f2f10e79d31ec889f52b', '6654f2c20e79d31ec889f520', '658a969c6adc144b84875e6a', '6654f3820e79d31ec889f550', '6654f31b0e79d31ec889f538']

# %%
query = {"_id": {"$in": [ObjectId(user) for user in top5_jaccard]}}
top5_predict_users = userCollection.find(query)


for user in top5_predict_users:
    print(f"_id: {user['_id']} - username: {user['username']}")
# Out:
# _id: 658a969c6adc144b84875e6a - username: user30
# _id: 6654f2c20e79d31ec889f520 - username: user31
# _id: 6654f2f10e79d31ec889f52b - username: user32
# _id: 6654f31b0e79d31ec889f538 - username: user33
# _id: 6654f3820e79d31ec889f550 - username: user36

# %% [markdown]
# ## 6.3 Thuật toán Adamic-Adar (AA)

# %% [markdown]
# ### Triển khai thuật toán Adamic Adar

# %%
def adamic_adar_index(G, u, v):
    # Tìm cách hàng xóm chung của node u và v
    neighbors_u = set(G.neighbors(u))
    neighbors_v = set(G.neighbors(v))
    common_neighbors = neighbors_u.intersection(neighbors_v)
    
    # Tính điểm Adamic-Adar
    aa_index = sum(1 / np.log10(G.degree(w)) for w in common_neighbors)
    
    return aa_index

# %%
adamic_adar_scores = []

for v in unconnected_nodes:
    score = adamic_adar_index(G_users, predict_node, v)
    adamic_adar_scores.append([predict_node, v, score])

predict_df = pd.DataFrame(adamic_adar_scores, columns=["From", "To", "Adamic-Adar Index"]) \
            .sort_values(by='Adamic-Adar Index', ascending=False)
predict_df
# Out:
#                         From                        To  Adamic-Adar Index
# 0   654fbb2b40cfec0440aaf1c7  6654f2f10e79d31ec889f52b           4.042280
# 22  654fbb2b40cfec0440aaf1c7  6654f3820e79d31ec889f550           3.211798
# 1   654fbb2b40cfec0440aaf1c7  6654f31b0e79d31ec889f538           3.211798
# 13  654fbb2b40cfec0440aaf1c7  6654f4aa0e79d31ec889f595           3.192005
# 2   654fbb2b40cfec0440aaf1c7  658a969c6adc144b84875e6a           3.169777
# 9   654fbb2b40cfec0440aaf1c7  6654f2c20e79d31ec889f520           3.169777
# 11  654fbb2b40cfec0440aaf1c7  6654f61b0e79d31ec889f5ee           2.553259
# 25  654fbb2b40cfec0440aaf1c7  6654f44c0e79d31ec889f57f           2.533467
# 27  654fbb2b40cfec0440aaf1c7  6654f5a30e79d31ec889f5cf           2.511238
# 3   654fbb2b40cfec0440aaf1c7  6654f5730e79d31ec889f5c5           2.381316
# 16  654fbb2b40cfec0440aaf1c7  6654f34a0e79d31ec889f544           2.361523
# 28  654fbb2b40cfec0440aaf1c7  6654f3dc0e79d31ec889f568           2.361523
# 17  654fbb2b40cfec0440aaf1c7  6654f41a0e79d31ec889f573           2.361523
# 4   654fbb2b40cfec0440aaf1c7  6654f5470e79d31ec889f5b7           2.339295
# 10  654fbb2b40cfec0440aaf1c7  6654f5180e79d31ec889f5aa           2.319503
# 23  654fbb2b40cfec0440aaf1c7  6654f3b30e79d31ec889f55c           1.660964
# 15  654fbb2b40cfec0440aaf1c7  658a8d484322ba2e40973103           1.531041
# 20  654fbb2b40cfec0440aaf1c7  6654f4760e79d31ec889f58a           1.508813
# 24  654fbb2b40cfec0440aaf1c7  658a8a556adc144b84875e50           1.508813
# 29  654fbb2b40cfec0440aaf1c7  6654f5f60e79d31ec889f5e4           0.850274
# 14  654fbb2b40cfec0440aaf1c7  6582feb4df8e015f44e26cf6           0.830482
# 7   654fbb2b40cfec0440aaf1c7  6654f5cc0e79d31ec889f5da           0.830482
# 19  654fbb2b40cfec0440aaf1c7  65684a74f0de8a23909ba7d9           0.658539
# 12  654fbb2b40cfec0440aaf1c7  656849d63198ea3afc9e37ef           0.658539
# 8   654fbb2b40cfec0440aaf1c7  6654f4e60e79d31ec889f5a3           0.658539
# 26  654fbb2b40cfec0440aaf1c7  6550ee9b9cb73328506de7a3           0.658539
# 30  654fbb2b40cfec0440aaf1c7  6551e902beb4280e4c0f2f0a           0.658539
# 18  654fbb2b40cfec0440aaf1c7  6573187bcb5de10ba8fa92ea           0.000000
# 21  654fbb2b40cfec0440aaf1c7  658e8ffe47a57302a4c5b97d           0.000000
# 6   654fbb2b40cfec0440aaf1c7  656752403f8339224440f530           0.000000
# 5   654fbb2b40cfec0440aaf1c7  6585bb530a44933edc12f0d5           0.000000

# %% [markdown]
# ### Lấy ra cặp cạnh được dự đoán liên kết có Adamic-Adar Index lớn nhất, và thông tin người dùng tương ứng

# %%
sorted_adamic_adar_scores = sorted(adamic_adar_scores, key=lambda x: x[2], reverse=True)
top5_adamic_adar = np.array(sorted_adamic_adar_scores[:5])[:, 1]

query = {"_id": {"$in": [ObjectId(user) for user in top5_adamic_adar]}}
top5_predict_users = userCollection.find(query)


for user in top5_predict_users:
    print(f"_id: {user['_id']} - username: {user['username']}")
# Out:
# _id: 658a969c6adc144b84875e6a - username: user30
# _id: 6654f2f10e79d31ec889f52b - username: user32
# _id: 6654f31b0e79d31ec889f538 - username: user33
# _id: 6654f3820e79d31ec889f550 - username: user36
# _id: 6654f4aa0e79d31ec889f595 - username: user42

# %% [markdown]
# ## 6.4 Thuật toán Katz Index

# %% [markdown]
# ### Triển khai thuật toán theo ma trận tương đồng

# %%
def katz_index_from_node(G, beta=0.1, target_node=None):
    # Tạo ma trận kề từ đồ thị
    A = nx.to_numpy_array(G)
    
    n = A.shape[0]
    I = np.eye(n)
    S = np.linalg.inv(I - beta * A) - I
    

    nodes = list(G.nodes())
    node_index = {node: idx for idx, node in enumerate(nodes)}
    target_index = node_index[target_node]
    katz_scores = S[target_index, :]
    neighbor_nodes = set(G.neighbors(target_node))
    
    # Loại các node đã có liên kết và chính node target
    results = []
    for i in range(n):
        if nodes[i] not in neighbor_nodes and nodes[i] != target_node:
            results.append((target_node, nodes[i], katz_scores[i]))
    
    return results

# %%
beta = 0.1
katz_scores = katz_index_from_node(G_users, beta, predict_node)

predict_df = pd.DataFrame(katz_scores, columns=["From", "To", "Katz Index"]) \
            .sort_values(by='Katz Index', ascending=False)
predict_df
# Out:
#                         From                        To  Katz Index
# 5   654fbb2b40cfec0440aaf1c7  6573187bcb5de10ba8fa92ea    0.016829
# 0   654fbb2b40cfec0440aaf1c7  6550ee9b9cb73328506de7a3    0.016813
# 6   654fbb2b40cfec0440aaf1c7  6582feb4df8e015f44e26cf6    0.015438
# 9   654fbb2b40cfec0440aaf1c7  658a8d484322ba2e40973103    0.015285
# 11  654fbb2b40cfec0440aaf1c7  658e8ffe47a57302a4c5b97d    0.010314
# 3   654fbb2b40cfec0440aaf1c7  656849d63198ea3afc9e37ef    0.001681
# 8   654fbb2b40cfec0440aaf1c7  658a8a556adc144b84875e50    0.001528
# 4   654fbb2b40cfec0440aaf1c7  65684a74f0de8a23909ba7d9    0.000153
# 29  654fbb2b40cfec0440aaf1c7  6654f5f60e79d31ec889f5e4    0.000000
# 28  654fbb2b40cfec0440aaf1c7  6654f5cc0e79d31ec889f5da    0.000000
# 19  654fbb2b40cfec0440aaf1c7  6654f41a0e79d31ec889f573    0.000000
# 27  654fbb2b40cfec0440aaf1c7  6654f5a30e79d31ec889f5cf    0.000000
# 26  654fbb2b40cfec0440aaf1c7  6654f5730e79d31ec889f5c5    0.000000
# 25  654fbb2b40cfec0440aaf1c7  6654f5470e79d31ec889f5b7    0.000000
# 24  654fbb2b40cfec0440aaf1c7  6654f5180e79d31ec889f5aa    0.000000
# 23  654fbb2b40cfec0440aaf1c7  6654f4e60e79d31ec889f5a3    0.000000
# 22  654fbb2b40cfec0440aaf1c7  6654f4aa0e79d31ec889f595    0.000000
# 21  654fbb2b40cfec0440aaf1c7  6654f4760e79d31ec889f58a    0.000000
# 20  654fbb2b40cfec0440aaf1c7  6654f44c0e79d31ec889f57f    0.000000
# 15  654fbb2b40cfec0440aaf1c7  6654f34a0e79d31ec889f544    0.000000
# 18  654fbb2b40cfec0440aaf1c7  6654f3dc0e79d31ec889f568    0.000000
# 17  654fbb2b40cfec0440aaf1c7  6654f3b30e79d31ec889f55c    0.000000
# 16  654fbb2b40cfec0440aaf1c7  6654f3820e79d31ec889f550    0.000000
# 1   654fbb2b40cfec0440aaf1c7  6551e902beb4280e4c0f2f0a    0.000000
# 14  654fbb2b40cfec0440aaf1c7  6654f31b0e79d31ec889f538    0.000000
# 13  654fbb2b40cfec0440aaf1c7  6654f2f10e79d31ec889f52b    0.000000
# 12  654fbb2b40cfec0440aaf1c7  6654f2c20e79d31ec889f520    0.000000
# 10  654fbb2b40cfec0440aaf1c7  658a969c6adc144b84875e6a    0.000000
# 7   654fbb2b40cfec0440aaf1c7  6585bb530a44933edc12f0d5    0.000000
# 2   654fbb2b40cfec0440aaf1c7  656752403f8339224440f530    0.000000
# 30  654fbb2b40cfec0440aaf1c7  6654f61b0e79d31ec889f5ee    0.000000

# %% [markdown]
# ### Lấy ra 5 đỉnh được dự đoán liên kết có Katz Index lớn nhất, và thông tin người dùng tương ứng

# %%
sorted_katz_scores = sorted(katz_scores, key=lambda x: x[2], reverse=True)
top5_katz_scores = np.array(sorted_katz_scores[:5])[:, 1]

query = {"_id": {"$in": [ObjectId(user) for user in top5_katz_scores]}}
top5_predict_users = userCollection.find(query)


for user in top5_predict_users:
    print(f"_id: {user['_id']} - username: {user['username']}")
# Out:
# _id: 6550ee9b9cb73328506de7a3 - username: yushino
# _id: 6573187bcb5de10ba8fa92ea - username: delwyn.lph_
# _id: 6582feb4df8e015f44e26cf6 - username: @vana_haha
# _id: 658a8d484322ba2e40973103 - username: bithao
# _id: 658e8ffe47a57302a4c5b97d - username: quichua333
